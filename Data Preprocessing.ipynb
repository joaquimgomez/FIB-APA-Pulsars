# %% [markdown]
# # Data Preprocessing

# %%
# %matplotlib inline

from scipy.io import arff
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = arff.loadarff("./data/HTRU2/HTRU_2.arff")
df = pd.DataFrame(data[0])

print(df)
# Out:
#        Profile_mean  Profile_stdev  Profile_skewness  Profile_kurtosis  \
# 0        140.562500      55.683782         -0.234571         -0.699648
# 1        102.507812      58.882430          0.465318         -0.515088
# 2        103.015625      39.341649          0.323328          1.051164
# 3        136.750000      57.178449         -0.068415         -0.636238
# 4         88.726562      40.672225          0.600866          1.123492
# 5         93.570312      46.698114          0.531905          0.416721
# 6        119.484375      48.765059          0.031460         -0.112168
# 7        130.382812      39.844056         -0.158323          0.389540
# 8        107.250000      52.627078          0.452688          0.170347
# 9        107.257812      39.496488          0.465882          1.162877
# 10       142.078125      45.288073         -0.320328          0.283953
# 11       133.257812      44.058244         -0.081060          0.115362
# ...

# %% [markdown]
# ### Lost Values

# %%
df.isnull().values.any() # Has no NaN/lost values
# Out:
# False

# %%
df.isna().values.any()
# Out:
# False

# %% [markdown]
# ### Outliers

# %% [markdown]
# ## Standarization

# %%
scaler = StandardScaler()

scaledData = scaler.fit_transform(df.drop(['class'], axis = 1))

stdDf = pd.DataFrame(scaledData, columns = df.columns[:-1])
stdDfWithClass = pd.concat([stdDf, df[['class']]], axis = 1)

# %% [markdown]
# ## PCA (Feature Extraction ?)

# %% [markdown]
# Correlation Matrix of "Normal" Data:

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_03c3ef7e_20e6_11ea_b083_f45c89bc9c43row0_col0 {
#             background-color:  #b40426;
#         }    #T_03c3ef7e_20e6_11ea_b083_f45c89bc9c43row0_col1 {
#             background-color:  #f7aa8c;
#         }    #T_03c3ef7e_20e6_11ea_b083_f45c89bc9c43row0_col2 {
#             background-color:  #3b4cc0;
#         }    #T_03c3ef7e_20e6_11ea_b083_f45c89bc9c43row0_col3 {
#             background-color:  #3b4cc0;
#         }    #T_03c3ef7e_20e6_11ea_b083_f45c89bc9c43row0_col4 {
#             background-color:  #7a9df8;
#         }    #T_03c3ef7e_20e6_11ea_b083_f45c89bc9c43row0_col5 {
#             background-color:  #97b8ff;
#         }    #T_03c3ef7e_20e6_11ea_b083_f45c89bc9c43row0_col6 {
#             background-color:  #eed0c0;
#         }    #T_03c3ef7e_20e6_11ea_b083_f45c89bc9c43row0_col7 {
#             background-color:  #d1dae9;
#         }    #T_03c3ef7e_20e6_11ea_b083_f45c89bc9c43row1_col0 {
#             background-color:  #f39577;
# ...

# %% [markdown]
# Correlation Matrix of Standarized Data:

# %%
corrStd = stdDf.corr()
corrStd.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_04cab8e4_20e6_11ea_b083_f45c89bc9c43row0_col0 {
#             background-color:  #b40426;
#         }    #T_04cab8e4_20e6_11ea_b083_f45c89bc9c43row0_col1 {
#             background-color:  #f7aa8c;
#         }    #T_04cab8e4_20e6_11ea_b083_f45c89bc9c43row0_col2 {
#             background-color:  #3b4cc0;
#         }    #T_04cab8e4_20e6_11ea_b083_f45c89bc9c43row0_col3 {
#             background-color:  #3b4cc0;
#         }    #T_04cab8e4_20e6_11ea_b083_f45c89bc9c43row0_col4 {
#             background-color:  #7a9df8;
#         }    #T_04cab8e4_20e6_11ea_b083_f45c89bc9c43row0_col5 {
#             background-color:  #97b8ff;
#         }    #T_04cab8e4_20e6_11ea_b083_f45c89bc9c43row0_col6 {
#             background-color:  #eed0c0;
#         }    #T_04cab8e4_20e6_11ea_b083_f45c89bc9c43row0_col7 {
#             background-color:  #d1dae9;
#         }    #T_04cab8e4_20e6_11ea_b083_f45c89bc9c43row1_col0 {
#             background-color:  #f39577;
# ...

# %% [markdown]
# Principal Component Analysis to reduce the dimensions of the data set:

# %%
pca = PCA(n_components = 8)

p = pca.fit_transform(stdDf)
