# %% [markdown]
# # Data Exploration & Preprocessing

# %%
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data

# %%
df = pd.read_csv("./data/HTRU2/HTRU_2.csv", names = ['Profile_mean', 'Profile_stdev', 'Profile_skewness', 
                                                      'Profile_kurtosis', 'DM_mean', 'DM_stdev', 'DM_skewness',
                                                      'DM_kurtosis', 'class'])

df
# Out:
#        Profile_mean  Profile_stdev  Profile_skewness  Profile_kurtosis  \
# 0        140.562500      55.683782         -0.234571         -0.699648
# 1        102.507812      58.882430          0.465318         -0.515088
# 2        103.015625      39.341649          0.323328          1.051164
# 3        136.750000      57.178449         -0.068415         -0.636238
# 4         88.726562      40.672225          0.600866          1.123492
# ...             ...            ...               ...               ...
# 17893    136.429688      59.847421         -0.187846         -0.738123
# 17894    122.554688      49.485605          0.127978          0.323061
# 17895    119.335938      59.935939          0.159363         -0.743025
# 17896    114.507812      53.902400          0.201161         -0.024789
# 17897     57.062500      85.797340          1.406391          0.089520
#
#           DM_mean   DM_stdev  DM_skewness  DM_kurtosis  class
# 0        3.199833  19.110426     7.975532    74.242225      0
# 1        1.677258  14.860146    10.576487   127.393580      0
# 2        3.121237  21.744669     7.735822    63.171909      0
# 3        3.642977  20.959280     6.896499    53.593661      0
# 4        1.178930  11.468720    14.269573   252.567306      0
# ...           ...        ...          ...          ...    ...
# 17893    1.296823  12.166062    15.450260   285.931022      0
# 17894   16.409699  44.626893     2.945244     8.297092      0
# 17895   21.430602  58.872000     2.499517     4.595173      0
# 17896    1.946488  13.381731    10.007967   134.238910      0
# 17897  188.306020  64.712562    -1.597527     1.429475      0
#
# [17898 rows x 9 columns]

# %% [markdown]
# ## Exploration

# %% [markdown]
# ### Lost values

# %%
df.isnull().values.any() # Has no NaN/lost values
# Out:
# False

# %%
df.isna().values.any()
# Out:
# False

# %% [markdown]
# ### Statistic analysis

# %% [markdown]
# Data boxplot:

# %%
sns.boxplot(data = df, palette="colorblind")

# %% [markdown]
# Description of the features:

# %%
df.describe()
# Out:
#        Profile_mean  Profile_stdev  Profile_skewness  Profile_kurtosis  \
# count  17898.000000   17898.000000      17898.000000      17898.000000
# mean     111.079968      46.549532          0.477857          1.770279
# std       25.652935       6.843189          1.064040          6.167913
# min        5.812500      24.772042         -1.876011         -1.791886
# 25%      100.929688      42.376018          0.027098         -0.188572
# 50%      115.078125      46.947479          0.223240          0.198710
# 75%      127.085938      51.023202          0.473325          0.927783
# max      192.617188      98.778911          8.069522         68.101622
#
#             DM_mean      DM_stdev   DM_skewness   DM_kurtosis         class
# count  17898.000000  17898.000000  17898.000000  17898.000000  17898.000000
# mean      12.614400     26.326515      8.303556    104.857709      0.091574
# std       29.472897     19.470572      4.506092    106.514540      0.288432
# min        0.213211      7.370432     -3.139270     -1.976976      0.000000
# 25%        1.923077     14.437332      5.781506     34.960504      0.000000
# 50%        2.801839     18.461316      8.433515     83.064556      0.000000
# 75%        5.464256     28.428104     10.702959    139.309331      0.000000
# max      223.392140    110.642211     34.539844   1191.000837      1.000000

# %%
pd.set_option('display.max_columns', 500)
df.groupby('class').describe()
#df.describe()
# Out:
#       Profile_mean                                                            \
#              count        mean        std        min         25%         50%
# class
# 0          16259.0  116.562726  17.475932  17.210938  105.253906  117.257812
# 1           1639.0   56.690608  30.007707   5.812500   31.777344   54.296875
#
#                               Profile_stdev                                  \
#               75%         max         count       mean       std        min
# class
# 0      128.285156  192.617188       16259.0  47.339741  6.182929  28.698714
# 1       79.277344  139.257812        1639.0  38.710598  8.033614  24.772042
#
#                                                   Profile_skewness            \
#              25%        50%        75%        max            count      mean
# class
# 0      43.384645  47.485647  51.315620  98.778911          16259.0  0.210440
# 1      32.284803  37.341297  43.759278  83.796909           1639.0  3.130655
#
#                                                                    \
#             std       min       25%       50%       75%       max
# class
# 0      0.334606 -1.876011  0.008650  0.186665  0.392892  4.785786
# 1      1.872861 -0.094888  1.556038  2.961258  4.586930  8.069522
#
#       Profile_kurtosis                                                       \
#                  count       mean        std       min       25%        50%
# class
# 0              16259.0   0.380844   1.027791 -1.791886 -0.221980   0.124107
# 1               1639.0  15.553576  13.997200 -1.139069  3.805492  11.609644
#
#                              DM_mean                                  \
#              75%        max    count       mean        std       min
# class
# 0       0.663383  24.872429  16259.0   8.863258  24.411409  0.213211
# 1      24.881853  68.101622   1639.0  49.825995  45.287932  0.486622
#
#                                                    DM_stdev             \
#              25%        50%        75%         max    count       mean
# class
# 0       1.857023   2.635452   4.227007  223.392140  16259.0  23.287984
# 1      12.759615  33.494983  78.313545  199.577759   1639.0  56.468963
#
#                                                                          \
#              std       min        25%        50%        75%         max
# class
# 0      16.651426  7.370432  14.138541  17.618420  24.517386  110.642211
# 1      19.731080  7.658623  43.333643  59.367088  70.985965  109.655345
#
#       DM_skewness                                                              \
#             count      mean       std      min       25%       50%        75%
# class
# 0         16259.0  8.862674  4.238626 -3.13927  6.615374  8.760010  10.935207
# 1          1639.0  2.757069  3.105945 -1.86232  0.756451  1.918327   3.709978
#
#                  DM_kurtosis                                               \
#              max       count        mean         std       min        25%
# class
# 0      34.539844     16259.0  113.620344  106.721930 -1.976976  47.580165
# 1      30.883882      1639.0   17.931728   50.896263 -1.874683  -0.228294
#
#
#              50%         75%          max
# class
# 0      90.674592  145.827223  1191.000837
# 1       2.585145   13.469687  1017.383180

# %% [markdown]
# Plotting 2 to 2 and densities:

# %%
col = df['class'].map({1:'r', 0:'b'})
pd.plotting.scatter_matrix(df, c=col, figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11b8687f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bc1b390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bc4a4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bc7b860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bcade10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bceb400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bd1c9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bd4ef98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bd4efd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11bdbdb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bdfc0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11be2c6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11be5fc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11be9d240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11becd7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bf00da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bf3d390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bf6d940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11bfa2ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bfdf4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c00fa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c050080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c07f630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c0b1be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c0f11d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c120780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c152d30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11c18e320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c1c18d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c1f3e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c230470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c261a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c296fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e64c5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e67fb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e6bf160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11e6ef710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e720cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e75f2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e790860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e7c2e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e7ff400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e8309b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e862f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e89e550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11e8d1b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e90f0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e93e6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e973c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e9b1240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e9e17f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ea13da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ea52390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ea82940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11eab5ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11eaf24e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11eb24a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11eb63080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11eb94630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ebc4be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ec031d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ec33780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ec65d30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11eca4320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ecd48d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ed06e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ed45470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ed74a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11eda9fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ede45c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ee17b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ee56160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11ee87710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11eeb9cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11eef62b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ef28860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ef5ae10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ef99400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11efc99b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11eff9f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f039550>]],
#       dtype=object)

# %% [markdown]
# Densities per class and feature:

# %%
dfPulsar = df.loc[df['class'] == 1]
dfNotPulsar = df.loc[df['class'] == 0]

for column in df.columns[:-1]:
    pulsars = dfPulsar[column]
    notPulsars = dfNotPulsar[column]

    p1=sns.kdeplot(pulsars, shade=True, color="r", label="pulsar")
    p1=sns.kdeplot(notPulsars, shade=True, color="b", label="not pulsar")
    plt.title(column)
    plt.show()

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Standarization

# %%
scaler = StandardScaler()

scaledData = scaler.fit_transform(df.drop(['class'], axis = 1))

stdDf = pd.DataFrame(scaledData, columns = df.columns[:-1])
stdDfWithClass = pd.concat([stdDf, df[['class']]], axis = 1)

# %%
stdDfWithClass.to_csv("./data/stdHTRU_2.csv", index = False)

# %% [markdown]
# ### Feature Extraction

# %% [markdown]
# Correlation Matrix of Data:

# %%
corrStd = stdDf.corr()
corrStd.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row0_col1 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row0_col4 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row0_col5 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row0_col6 {
#             background-color:  #eed0c0;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row0_col7 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row1_col0 {
#             background-color:  #f39577;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row1_col2 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row1_col3 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row1_col4 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row1_col5 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row1_col6 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row1_col7 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row2_col1 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row2_col3 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row2_col4 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row2_col5 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row2_col6 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row2_col7 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row3_col0 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row3_col2 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row3_col4 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row3_col5 {
#             background-color:  #f7b497;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row3_col6 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row3_col7 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row4_col0 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row4_col1 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row4_col2 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row4_col3 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row4_col5 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row4_col6 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row4_col7 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row5_col0 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row5_col1 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row5_col2 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row5_col3 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row5_col4 {
#             background-color:  #de614d;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row5_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row5_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row6_col0 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row6_col1 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row6_col2 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row6_col3 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row6_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row6_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row6_col7 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row7_col0 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row7_col1 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row7_col2 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_bcbe439e_2b4f_11ea_927a_f45c89bc9c43row7_col3 {
#             background-color:  #a1c0ff;
#             color:  #000000;

# %% [markdown]
# In order to improve the performance of ML models that will be affected by the correlation of features and irrelevant variables, we will remove the correlated features (with correlation higher than 0.9).

# %%
features = np.full((corrStd.shape[0],), True, dtype=bool)
for i in range(corrStd.shape[0]):
    for j in range(i+1, corrStd.shape[0]):
        if corrStd.iloc[i,j] >= 0.9:
            if features[j]:
                features[j] = False

selectedFeatures = stdDf.columns[features]

noCorrStdData = stdDf[selectedFeatures]

# %%
noCorrStdDfWithClassData = pd.concat([noCorrStdData, df[['class']]], axis = 1)

# %%
corrNoCorrStd = noCorrStdDfWithClassData.corr()
corrNoCorrStd.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row0_col1 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row0_col3 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row0_col4 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row0_col5 {
#             background-color:  #eed0c0;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row1_col0 {
#             background-color:  #f39577;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row1_col2 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row1_col3 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row1_col4 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row1_col5 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row1_col6 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row2_col3 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row2_col4 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row2_col5 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row2_col6 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row3_col0 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row3_col1 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row3_col2 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row3_col4 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row3_col5 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row3_col6 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row4_col0 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row4_col1 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row4_col2 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row4_col3 {
#             background-color:  #de614d;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row4_col6 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row5_col0 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row5_col1 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row5_col2 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row5_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row5_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row5_col6 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row6_col0 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row6_col1 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row6_col2 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row6_col3 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row6_col4 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row6_col5 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Profile_mean</th>        <th class="col_heading level0 col1" >Profile_stdev</th>        <th class="col_heading level0 col2" >Profile_skewness</th>        <th class="col_heading level0 col3" >DM_mean</th>        <th class="col_heading level0 col4" >DM_stdev</th>        <th class="col_heading level0 col5" >DM_skewness</th>        <th class="col_heading level0 col6" >class</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43level0_row0" class="row_heading level0 row0" >Profile_mean</th>
#                         <td id="T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row0_col1" class="data row0 col1" >0.547137</td>
#                         <td id="T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row0_col2" class="data row0 col2" >-0.873898</td>
#                         <td id="T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row0_col3" class="data row0 col3" >-0.298841</td>
#                         <td id="T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row0_col4" class="data row0 col4" >-0.307016</td>
#                         <td id="T_bcfc779a_2b4f_11ea_927a_f45c89bc9c43row0_col5" class="data row0 col5" >0.234331</td>
#                         <td id=

# %%
noCorrStdDfWithClassData.to_csv("./data/noCorrStdHTRU_2.csv", index = False)
